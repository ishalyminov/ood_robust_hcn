# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="vae.png" width="300">

# %%
from modified import ModifiedBasicDecoder, ModifiedBeamSearchDecoder

import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'word_dropout_rate': 0.8,
    'embed_dims': 128,
    'rnn_size': 128,
    'latent_size': 16,
    'beam_width': 5,
    'num_sampled': 1000,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 10,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}
    
    PARAMS['vocab_size'] = len(PARAMS['word2idx'])

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=None, index_from=index_from)
    return (X_train, X_test)


def word_dropout(x):
    is_dropped = np.random.binomial(1, PARAMS['word_dropout_rate'], x.shape)
    fn = np.vectorize(lambda x, k: PARAMS['word2idx']['<unk>'] if (
        k and (x not in range(4))) else x)
    return fn(x, is_dropped)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = word_dropout(X)
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def reparam_trick(z_mean, z_logvar):
    gaussian = tf.truncated_normal(tf.shape(z_logvar))
    z = z_mean + tf.exp(0.5 * z_logvar) * gaussian
    return z


def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))


def kl_loss_fn(mean, gamma):
    return 0.5 * tf.reduce_sum(
        tf.exp(gamma) + tf.square(mean) - 1 - gamma) / tf.to_float(tf.shape(mean)[0])

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())


def forward(inputs, labels, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder'):
        embedding = tf.get_variable('lookup_table', [len(PARAMS['word2idx']), PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_logvar = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    z = reparam_trick(z_mean, z_logvar)
        
    with tf.variable_scope('Decoder'):
        init_state = tf.layers.dense(z, PARAMS['rnn_size'], tf.nn.elu)
        output_proj = tf.layers.Dense(len(PARAMS['word2idx']), _scope='decoder/output_proj')
        dec_cell = rnn_cell()
        
        if is_training:
            dec_seq_len = tf.count_nonzero(labels['dec_out'], 1, dtype=tf.int32)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = tf.nn.embedding_lookup(embedding, labels['dec_inp']),
                sequence_length = dec_seq_len)
            decoder = ModifiedBasicDecoder(
                cell = dec_cell,
                helper = helper,
                initial_state = init_state,
                concat_z = z)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            rnn_output = decoder_output.rnn_output
            return rnn_output, output_proj(rnn_output), (z_mean, z_logvar)
        else:
            decoder = ModifiedBeamSearchDecoder(
                cell = dec_cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([PARAMS['word2idx']['<start>']], tf.int32),
                                       [batch_sz]),
                end_token = PARAMS['word2idx']['<end>'],
                initial_state = tf.contrib.seq2seq.tile_batch(init_state, PARAMS['beam_width']),
                beam_width = PARAMS['beam_width'],
                output_layer = output_proj,
                concat_z = tf.tile(tf.expand_dims(z, 1), [1, PARAMS['beam_width'], 1]))
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder)
            return decoder_output.predicted_ids[:, :, 0]

# %%
def model_fn(features, labels, mode):
    logits_or_ids = forward(features, labels, mode)        
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        rnn_output, logits, (z_mean, z_logvar) = logits_or_ids
        
        global_step = tf.train.get_global_step()
        
        with tf.variable_scope('Decoder/decoder/output_proj', reuse=True):
            _weights = tf.transpose(tf.get_variable('kernel'))
            _biases = tf.get_variable('bias')
        
        mask = tf.reshape(tf.to_float(tf.sign(labels['dec_out'])), [-1])
        
        nll_loss = tf.reduce_sum(mask * tf.nn.sampled_softmax_loss(
            weights = _weights,
            biases = _biases,
            labels = tf.reshape(labels['dec_out'], [-1, 1]),
            inputs = tf.reshape(rnn_output, [-1, PARAMS['rnn_size']]),
            num_sampled = PARAMS['num_sampled'],
            num_classes = PARAMS['vocab_size'],
        )) / tf.to_float(tf.shape(features)[0])
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = kl_loss_fn(z_mean, z_logvar)
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(
            clip_grads(loss_op),
            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))

    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12419e908>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 156.84924, step = 1
# INFO:tensorflow:nll_loss = 156.84924, kl_w = 0.006692851, kl_loss = 4.5167835e-05
# INFO:tensorflow:global_step/sec: 3.09239
# INFO:tensorflow:loss = 89.51066, step = 101 (32.340 sec)
# INFO:tensorflow:nll_loss = 88.51117, kl_w = 0.007897083, kl_loss = 126.56387 (32.340 sec)
# INFO:tensorflow:global_step/sec: 2.86958
# INFO:tensorflow:loss = 86.11752, step = 201 (34.847 sec)
# INFO:tensorflow:nll_loss = 85.52453, kl_w = 0.009315956, kl_loss = 63.65396 (34.847 sec)
# INFO:tensorflow:global_step/sec: 2.96334
# INFO:tensorflow:loss = 84.22123, step = 301 (33.745 sec)
# INFO:tensorflow:nll_loss = 83.73018, kl_w = 0.010986943, kl_loss = 44.69385 (33.745 sec)
# INFO:tensorflow:global_step/sec: 2.98837
# INFO:tensorflow:loss = 83.676674, step = 401 (33.463 sec)
# INFO:tensorflow:nll_loss = 83.174805, kl_w = 0.012953726, kl_loss = 38.74327 (33.463 sec)
# INFO:tensorflow:global_step/sec: 3.16333
# INFO:tensorflow:loss = 83.66508, step = 501 (31.612 sec)
# INFO:tensorflow:nll_loss = 83.19443, kl_w = 0.015267149, kl_loss = 30.827766 (31.612 sec)
# INFO:tensorflow:global_step/sec: 3.26359
# INFO:tensorflow:loss = 81.73362, step = 601 (30.641 sec)
# INFO:tensorflow:nll_loss = 81.364716, kl_w = 0.01798621, kl_loss = 20.510593 (30.641 sec)
# INFO:tensorflow:global_step/sec: 3.0388
# INFO:tensorflow:loss = 83.021065, step = 701 (32.907 sec)
# INFO:tensorflow:nll_loss = 82.74098, kl_w = 0.021179108, kl_loss = 13.224412 (32.907 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 85.32215.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i this this this this it it it it it it it it it <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: i this i i it it it it it it it it it it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 84.17679, step = 783
# INFO:tensorflow:nll_loss = 83.81665, kl_w = 0.024205629, kl_loss = 14.87817
# INFO:tensorflow:global_step/sec: 3.0666
# INFO:tensorflow:loss = 78.91054, step = 883 (32.611 sec)
# INFO:tensorflow:nll_loss = 78.43107, kl_w = 0.028470589, kl_loss = 16.840935 (32.611 sec)
# INFO:tensorflow:global_step/sec: 3.05121
# INFO:tensorflow:loss = 76.104004, step = 983 (32.774 sec)
# INFO:tensorflow:nll_loss = 75.478775, kl_w = 0.033461247, kl_loss = 18.68523 (32.774 sec)
# INFO:tensorflow:global_step/sec: 3.02377
# INFO:tensorflow:loss = 75.51568, step = 1083 (33.071 sec)
# INFO:tensorflow:nll_loss = 74.847275, kl_w = 0.039291352, kl_loss = 17.01149 (33.072 sec)
# INFO:tensorflow:global_step/sec: 3.06787
# INFO:tensorflow:loss = 79.501755, step = 1183 (32.596 sec)
# INFO:tensorflow:nll_loss = 78.802444, kl_w = 0.04608883, kl_loss = 15.1730175 (32.595 sec)
# INFO:tensorflow:global_step/sec: 3.14408
# INFO:tensorflow:loss = 79.37513, step = 1283 (31.806 sec)
# INFO:tensorflow:nll_loss = 78.56477, kl_w = 0.053996176, kl_loss = 15.007691 (31.806 sec)
# INFO:tensorflow:global_step/sec: 2.89742
# INFO:tensorflow:loss = 77.556656, step = 1383 (34.513 sec)
# INFO:tensorflow:nll_loss = 76.56862, kl_w = 0.06317033, kl_loss = 15.640845 (34.513 sec)
# INFO:tensorflow:global_step/sec: 2.9299
# INFO:tensorflow:loss = 75.86593, step = 1483 (34.132 sec)
# INFO:tensorflow:nll_loss = 74.728516, kl_w = 0.07378165, kl_loss = 15.415974 (34.132 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 72.333984.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i movie this movie this movie this movie this movie the the the movie <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is one of the worst movie i seen this movie it it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1565 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 71.70474, step = 1565
# INFO:tensorflow:nll_loss = 70.29488, kl_w = 0.08368247, kl_loss = 16.847675
# INFO:tensorflow:global_step/sec: 2.91481
# INFO:tensorflow:loss = 69.912125, step = 1665 (34.309 sec)
# INFO:tensorflow:nll_loss = 68.14949, kl_w = 0.09738124, kl_loss = 18.100357 (34.309 sec)
# INFO:tensorflow:global_step/sec: 3.18499
# INFO:tensorflow:loss = 74.50872, step = 1765 (31.397 sec)
# INFO:tensorflow:nll_loss = 72.652405, kl_w = 0.11304584, kl_loss = 16.420918 (31.397 sec)
# INFO:tensorflow:global_step/sec: 3.27734
# INFO:tensorflow:loss = 72.75928, step = 1865 (30.513 sec)
# INFO:tensorflow:nll_loss = 70.616165, kl_w = 0.13086486, kl_loss = 16.376532 (30.513 sec)
# INFO:tensorflow:global_step/sec: 3.31852
# INFO:tensorflow:loss = 70.72015, step = 1965 (30.134 sec)
# INFO:tensorflow:nll_loss = 68.22257, kl_w = 0.15101443, kl_loss = 16.53872 (30.134 sec)
# INFO:tensorflow:global_step/sec: 3.31997
# INFO:tensorflow:loss = 72.5149, step = 2065 (30.120 sec)
# INFO:tensorflow:nll_loss = 69.79782, kl_w = 0.17364664, kl_loss = 15.647158 (30.120 sec)
# INFO:tensorflow:global_step/sec: 3.13907
# INFO:tensorflow:loss = 68.97729, step = 2165 (31.856 sec)
# INFO:tensorflow:nll_loss = 65.68031, kl_w = 0.19887616, kl_loss = 16.57801 (31.857 sec)
# INFO:tensorflow:global_step/sec: 3.08077
# INFO:tensorflow:loss = 68.11235, step = 2265 (32.460 sec)
# INFO:tensorflow:nll_loss = 64.57591, kl_w = 0.22676536, kl_loss = 15.595131 (32.460 sec)
# INFO:tensorflow:Saving checkpoints for 2346 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 66.66642.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie that i have this movie of the most of the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is one of the time and it is it and it is <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2347 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 66.79067, step = 2347
# INFO:tensorflow:nll_loss = 62.88064, kl_w = 0.25161827, kl_loss = 15.539554
# INFO:tensorflow:global_step/sec: 3.00977
# INFO:tensorflow:loss = 71.159096, step = 2447 (33.227 sec)
# INFO:tensorflow:nll_loss = 66.94284, kl_w = 0.2842792, kl_loss = 14.831383 (33.226 sec)
# INFO:tensorflow:global_step/sec: 3.05542
# INFO:tensorflow:loss = 68.88188, step = 2547 (32.728 sec)
# INFO:tensorflow:nll_loss = 64.30664, kl_w = 0.31937042, kl_loss = 14.325805 (32.729 sec)
# INFO:tensorflow:global_step/sec: 3.19163
# INFO:tensorflow:loss = 68.9099, step = 2647 (31.332 sec)
# INFO:tensorflow:nll_loss = 63.82857, kl_w = 0.35663486, kl_loss = 14.247984 (31.332 sec)
# INFO:tensorflow:global_step/sec: 3.08161
# INFO:tensorflow:loss = 69.57863, step = 2747 (32.451 sec)
# INFO:tensorflow:nll_loss = 64.092384, kl_w = 0.39571938, kl_loss = 13.863969 (32.452 sec)
# INFO:tensorflow:global_step/sec: 3.03718
# INFO:tensorflow:loss = 66.67361, step = 2847 (32.924 sec)
# INFO:tensorflow:nll_loss = 60.908474, kl_w = 0.43618327, kl_loss = 13.217224 (32.924 sec)
# INFO:tensorflow:global_step/sec: 3.08817
# INFO:tensorflow:loss = 67.29543, step = 2947 (32.382 sec)
# INFO:tensorflow:nll_loss = 61.183594, kl_w = 0.47751516, kl_loss = 12.79925 (32.382 sec)
# INFO:tensorflow:global_step/sec: 2.99561
# INFO:tensorflow:loss = 67.074234, step = 3047 (33.382 sec)
# INFO:tensorflow:nll_loss = 60.775288, kl_w = 0.5191573, kl_loss = 12.133017 (33.382 sec)
# INFO:tensorflow:Saving checkpoints for 3128 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 69.79216.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie that i have seen in the best of the characters <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is one of those movies and it is one and i have <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3129 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 66.76859, step = 3129
# INFO:tensorflow:nll_loss = 59.887238, kl_w = 0.55313194, kl_loss = 12.440711
# INFO:tensorflow:global_step/sec: 2.95542
# INFO:tensorflow:loss = 65.99065, step = 3229 (33.838 sec)
# INFO:tensorflow:nll_loss = 58.819736, kl_w = 0.5938731, kl_loss = 12.074814 (33.838 sec)
# INFO:tensorflow:global_step/sec: 3.0654
# INFO:tensorflow:loss = 66.71266, step = 3329 (32.622 sec)
# INFO:tensorflow:nll_loss = 59.412994, kl_w = 0.6333619, kl_loss = 11.525276 (32.622 sec)
# INFO:tensorflow:global_step/sec: 3.17144
# INFO:tensorflow:loss = 67.65394, step = 3429 (31.532 sec)
# INFO:tensorflow:nll_loss = 60.17337, kl_w = 0.6711373, kl_loss = 11.146111 (31.533 sec)
# INFO:tensorflow:global_step/sec: 2.95991
# INFO:tensorflow:loss = 74.31069, step = 3529 (33.784 sec)
# INFO:tensorflow:nll_loss = 67.22857, kl_w = 0.7068222, kl_loss = 10.0196705 (33.784 sec)
# INFO:tensorflow:global_step/sec: 3.08216
# INFO:tensorflow:loss = 71.854866, step = 3629 (32.445 sec)
# INFO:tensorflow:nll_loss = 64.49328, kl_w = 0.7401343, kl_loss = 9.946283 (32.445 sec)
# INFO:tensorflow:global_step/sec: 3.08429
# INFO:tensorflow:loss = 73.2321, step = 3729 (32.422 sec)
# INFO:tensorflow:nll_loss = 65.951866, kl_w = 0.7708882, kl_loss = 9.443953 (32.422 sec)
# INFO:tensorflow:global_step/sec: 3.14441
# INFO:tensorflow:loss = 72.19332, step = 3829 (31.803 sec)
# INFO:tensorflow:nll_loss = 64.67302, kl_w = 0.79899096, kl_loss = 9.412247 (31.803 sec)
# INFO:tensorflow:Saving checkpoints for 3910 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 71.06906.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie that i have seen this one of the time and <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a lot of my time to see it is worth a <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3911 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 69.573715, step = 3911
# INFO:tensorflow:nll_loss = 61.61915, kl_w = 0.82004714, kl_loss = 9.700136
# INFO:tensorflow:global_step/sec: 2.97554
# INFO:tensorflow:loss = 66.35769, step = 4011 (33.609 sec)
# INFO:tensorflow:nll_loss = 57.966305, kl_w = 0.84334546, kl_loss = 9.950111 (33.609 sec)
# INFO:tensorflow:global_step/sec: 2.90204
# INFO:tensorflow:loss = 73.542496, step = 4111 (34.458 sec)
# INFO:tensorflow:nll_loss = 66.03313, kl_w = 0.8641271, kl_loss = 8.690121 (34.458 sec)
# INFO:tensorflow:global_step/sec: 3.1819
# INFO:tensorflow:loss = 71.99678, step = 4211 (31.428 sec)
# INFO:tensorflow:nll_loss = 64.203384, kl_w = 0.88253593, kl_loss = 8.830687 (31.427 sec)
# INFO:tensorflow:global_step/sec: 3.09655
# INFO:tensorflow:loss = 71.53158, step = 4311 (32.294 sec)
# INFO:tensorflow:nll_loss = 63.660187, kl_w = 0.89874285, kl_loss = 8.7582245 (32.294 sec)
# INFO:tensorflow:global_step/sec: 2.85683
# INFO:tensorflow:loss = 72.35594, step = 4411 (35.004 sec)
# INFO:tensorflow:nll_loss = 64.40447, kl_w = 0.9129343, kl_loss = 8.709796 (35.004 sec)
# INFO:tensorflow:global_step/sec: 3.05868
# INFO:tensorflow:loss = 68.56282, step = 4511 (32.695 sec)
# INFO:tensorflow:nll_loss = 60.188442, kl_w = 0.92530197, kl_loss = 9.050423 (32.695 sec)
# INFO:tensorflow:global_step/sec: 3.24389
# INFO:tensorflow:loss = 68.388916, step = 4611 (30.826 sec)
# INFO:tensorflow:nll_loss = 60.09649, kl_w = 0.93603605, kl_loss = 8.859094 (30.825 sec)
# INFO:tensorflow:Saving checkpoints for 4692 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 67.85171.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i love the worst movie i have seen this movie one of the best <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a fan of my time i watched it is me to <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4693 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 69.19583, step = 4693
# INFO:tensorflow:nll_loss = 60.89403, kl_w = 0.94374704, kl_loss = 8.796636
# INFO:tensorflow:global_step/sec: 3.09967
# INFO:tensorflow:loss = 67.26343, step = 4793 (32.263 sec)
# INFO:tensorflow:nll_loss = 58.85718, kl_w = 0.95196813, kl_loss = 8.830387 (32.263 sec)
# INFO:tensorflow:global_step/sec: 3.21578
# INFO:tensorflow:loss = 71.98114, step = 4893 (31.097 sec)
# INFO:tensorflow:nll_loss = 64.10393, kl_w = 0.9590399, kl_loss = 8.213641 (31.097 sec)
# INFO:tensorflow:global_step/sec: 3.11963
# INFO:tensorflow:loss = 71.95244, step = 4993 (32.055 sec)
# INFO:tensorflow:nll_loss = 63.978188, kl_w = 0.9651086, kl_loss = 8.262545 (32.055 sec)
# INFO:tensorflow:global_step/sec: 3.10664
# INFO:tensorflow:loss = 72.0596, step = 5093 (32.190 sec)
# INFO:tensorflow:nll_loss = 63.7858, kl_w = 0.97030604, kl_loss = 8.527002 (32.191 sec)
# INFO:tensorflow:global_step/sec: 3.0148
# INFO:tensorflow:loss = 70.916466, step = 5193 (33.169 sec)
# INFO:tensorflow:nll_loss = 62.582848, kl_w = 0.97474945, kl_loss = 8.549496 (33.170 sec)
# INFO:tensorflow:global_step/sec: 3.09681
# INFO:tensorflow:loss = 67.24357, step = 5293 (32.290 sec)
# INFO:tensorflow:nll_loss = 58.53064, kl_w = 0.9785427, kl_loss = 8.903986 (32.290 sec)
# INFO:tensorflow:global_step/sec: 3.05284
# INFO:tensorflow:loss = 69.86395, step = 5393 (32.757 sec)
# INFO:tensorflow:nll_loss = 61.399246, kl_w = 0.9817768, kl_loss = 8.621822 (32.757 sec)
# INFO:tensorflow:Saving checkpoints for 5474 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 68.251205.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this is the worst movie ever seen this movie is one of the best <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a waste of time i've seen this movie i've seen it is <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5475 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 77.25666, step = 5475
# INFO:tensorflow:nll_loss = 68.36436, kl_w = 0.98406756, kl_loss = 9.036274
# INFO:tensorflow:global_step/sec: 2.79174
# INFO:tensorflow:loss = 70.71189, step = 5575 (35.821 sec)
# INFO:tensorflow:nll_loss = 62.076195, kl_w = 0.9864804, kl_loss = 8.7540455 (35.821 sec)
# INFO:tensorflow:global_step/sec: 2.73662
# INFO:tensorflow:loss = 71.892494, step = 5675 (36.541 sec)
# INFO:tensorflow:nll_loss = 63.680157, kl_w = 0.98853207, kl_loss = 8.3076105 (36.542 sec)
# INFO:tensorflow:global_step/sec: 2.7222
# INFO:tensorflow:loss = 70.79995, step = 5775 (36.735 sec)
# INFO:tensorflow:nll_loss = 62.494, kl_w = 0.9902755, kl_loss = 8.387513 (36.735 sec)
# INFO:tensorflow:global_step/sec: 2.78811
# INFO:tensorflow:loss = 66.60954, step = 5875 (35.866 sec)
# INFO:tensorflow:nll_loss = 57.538837, kl_w = 0.9917561, kl_loss = 9.146106 (35.866 sec)
# INFO:tensorflow:global_step/sec: 2.97841
# INFO:tensorflow:loss = 69.16531, step = 5975 (33.575 sec)
# INFO:tensorflow:nll_loss = 60.509003, kl_w = 0.99301285, kl_loss = 8.717218 (33.575 sec)
# INFO:tensorflow:global_step/sec: 3.02814
# INFO:tensorflow:loss = 67.55208, step = 6075 (33.024 sec)
# INFO:tensorflow:nll_loss = 58.747597, kl_w = 0.9940791, kl_loss = 8.856924 (33.023 sec)
# INFO:tensorflow:global_step/sec: 2.90777
# INFO:tensorflow:loss = 69.31873, step = 6175 (34.391 sec)
# INFO:tensorflow:nll_loss = 60.69129, kl_w = 0.99498355, kl_loss = 8.670938 (34.391 sec)
# INFO:tensorflow:Saving checkpoints for 6256 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 71.32247.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i love this movie and i think it was the first of the best <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time to watch your time to watch it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6257 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 69.49514, step = 6257
# INFO:tensorflow:nll_loss = 60.635017, kl_w = 0.9956215, kl_loss = 8.899088
# INFO:tensorflow:global_step/sec: 3.01849
# INFO:tensorflow:loss = 70.706, step = 6357 (33.130 sec)
# INFO:tensorflow:nll_loss = 62.2969, kl_w = 0.9962913, kl_loss = 8.440403 (33.130 sec)
# INFO:tensorflow:global_step/sec: 3.05042
# INFO:tensorflow:loss = 70.45711, step = 6457 (32.783 sec)
# INFO:tensorflow:nll_loss = 62.005234, kl_w = 0.99685884, kl_loss = 8.478504 (32.783 sec)
# INFO:tensorflow:global_step/sec: 2.93972
# INFO:tensorflow:loss = 68.7057, step = 6557 (34.017 sec)
# INFO:tensorflow:nll_loss = 59.493042, kl_w = 0.9973398, kl_loss = 9.237238 (34.016 sec)
# INFO:tensorflow:global_step/sec: 3.01951
# INFO:tensorflow:loss = 66.00239, step = 6657 (33.118 sec)
# INFO:tensorflow:nll_loss = 57.00882, kl_w = 0.99774724, kl_loss = 9.013872 (33.118 sec)
# INFO:tensorflow:global_step/sec: 2.98089
# INFO:tensorflow:loss = 66.15622, step = 6757 (33.547 sec)
# INFO:tensorflow:nll_loss = 57.20526, kl_w = 0.99809235, kl_loss = 8.968067 (33.547 sec)
# INFO:tensorflow:global_step/sec: 2.98414
# INFO:tensorflow:loss = 66.60782, step = 6857 (33.510 sec)
# INFO:tensorflow:nll_loss = 57.579514, kl_w = 0.99838483, kl_loss = 9.0429125 (33.510 sec)
# INFO:tensorflow:global_step/sec: 2.89444
# INFO:tensorflow:loss = 72.231674, step = 6957 (34.549 sec)
# INFO:tensorflow:nll_loss = 63.540855, kl_w = 0.9986324, kl_loss = 8.702724 (34.549 sec)
# INFO:tensorflow:Saving checkpoints for 7038 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 71.18652.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie i think it is one of my favorite of my <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time to watch this movie i have seen <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7039 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:loss = 67.95318, step = 7039
# INFO:tensorflow:nll_loss = 58.835907, kl_w = 0.99880695, kl_loss = 9.1281595
# INFO:tensorflow:global_step/sec: 2.99434
# INFO:tensorflow:loss = 65.082794, step = 7139 (33.397 sec)
# INFO:tensorflow:nll_loss = 55.938393, kl_w = 0.9989899, kl_loss = 9.153648 (33.398 sec)
# INFO:tensorflow:global_step/sec: 3.1126
# INFO:tensorflow:loss = 65.89795, step = 7239 (32.128 sec)
# INFO:tensorflow:nll_loss = 56.55067, kl_w = 0.9991448, kl_loss = 9.355278 (32.127 sec)
# INFO:tensorflow:global_step/sec: 3.02303
# INFO:tensorflow:loss = 67.97936, step = 7339 (33.080 sec)
# INFO:tensorflow:nll_loss = 59.235886, kl_w = 0.999276, kl_loss = 8.74981 (33.080 sec)
# INFO:tensorflow:global_step/sec: 3.11264
# INFO:tensorflow:loss = 70.66269, step = 7439 (32.126 sec)
# INFO:tensorflow:nll_loss = 61.93919, kl_w = 0.999387, kl_loss = 8.728846 (32.127 sec)
# INFO:tensorflow:global_step/sec: 2.99345
# INFO:tensorflow:loss = 71.91047, step = 7539 (33.406 sec)
# INFO:tensorflow:nll_loss = 63.22177, kl_w = 0.99948114, kl_loss = 8.693206 (33.406 sec)
# INFO:tensorflow:global_step/sec: 2.94122
# INFO:tensorflow:loss = 69.74791, step = 7639 (34.000 sec)
# INFO:tensorflow:nll_loss = 60.741592, kl_w = 0.9995608, kl_loss = 9.010279 (34.000 sec)
# INFO:tensorflow:global_step/sec: 3.19497
# INFO:tensorflow:loss = 65.615486, step = 7739 (31.299 sec)
# INFO:tensorflow:nll_loss = 56.410316, kl_w = 0.9996282, kl_loss = 9.208596 (31.299 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt.
# INFO:tensorflow:Loss for final step: 66.7313.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp3fyvap01/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i loved the worst movies i have seen this one of the worst movies <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is one of those time i saw this movie if you are <end>
